# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
original_image = cv2.imread('/Users/yacoubadambachar/Desktop/Unknown')

# %%
plt.imshow(original_image)
plt.title('tree')
plt.show()

# %%
gray = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.title('my picture')
plt.show()

# %% [markdown]
# #Goruntu kirpma

# %%
cropped = original_image[5:125,5:170]

# %%
plt.title('cropped image')
plt.imshow(cropped)

# %%
cropped1 = original_image[15:125,15:170]

# %%
plt.title('cropped image')
plt.imshow(cropped1)

# %%
gray1 = cv2.cvtColor(cropped1, cv2.COLOR_BGR2GRAY)
plt.imshow(gray1)
plt.title('my picture')
plt.show()
